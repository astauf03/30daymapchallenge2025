# %% [markdown]
# # Goal: Make a map of Sangenjaya, Tokyo

# %% [markdown]
# ## 1. import libraries

# %%
import osmnx as ox
import geopandas as gpd
from shapely.geometry import Point

# %% [markdown]
# ## 2. Geocode Sangenjaya, Tokyo to get its boundary polygon

# %%
# Geocode Sangenjaya, Tokyo to get its boundary polygon and create a buffer of 8 km around it
sstation_name = "Sangenjaya Station, Setagaya, Tokyo, Japan"
station_point = ox.geocode(station_name)

station = gpd.GeoDataFrame(geometry=[Point(station_point)], crs="EPSG:4326")

#create buffer of 8 km around the station
station_buffer = station.to_crs(epsg=3857).buffer(8000).to_crs(epsg=4326)

# %% [markdown]
# ## Download OSM features

# %%
# 4. Convert buffer (GeoSeries) to proper GeoDataFrame
buffer_poly = gpd.GeoDataFrame(geometry=[station_buffer.iloc[0]], crs="EPSG:4326")

# %%
tags_name = {"name": True}  # all features with any name tag
names = ox.features_from_polygon(buffer_poly.geometry[0], tags=tags_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 tags_name = {"name": True}  # all features with any name tag
# ----> 2 names = ox.features_from_polygon(buffer_poly.geometry[0], tags=tags_name)
#
# File c:\Users\astau\anaconda3\envs\geospatial\lib\site-packages\osmnx\features.py:334, in features_from_polygon(polygon, tags)
#     331 response_jsons = _overpass._download_overpass_features(polygon, tags)
#     333 # create GeoDataFrame from the downloaded data
# --> 334 return _create_gdf(response_jsons, polygon, tags)
#
# File c:\Users\astau\anaconda3\envs\geospatial\lib\site-packages\osmnx\features.py:423, in _create_gdf(response_jsons, polygon, tags)
#     420 relation_types = {"boundary", "multipolygon"}
#     422 # extract geometries from the downloaded osm data
# --> 423 for response_json in response_jsons:
#     424     response_count += 1
# ...
